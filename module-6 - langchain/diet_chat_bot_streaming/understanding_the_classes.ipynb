# %%
# Source - https://stackoverflow.com/a/5399339
# Posted by pv., modified by community. See post 'Timeline' for change history
# Retrieved 2026-05-17, License - CC BY-SA 4.0

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## The DietChatBot

# %%
from logic import DietChatBot

# %%
bot = DietChatBot()
# Out:
# /home/sacha/RAG-course-deeplearning/module-6 - langchain/diet_chat_bot_streaming/logic.py:28: LangChainDeprecationWarning: `connection_string` was deprecated in LangChain 0.2.2 and will be removed in 1.0. Use connection instead.
#   self._initialize_history()

# %%
bot.session_id
# Out:
# 'Diet Chat - 2026-05-17 21:15:55'

# %%
query = "Is there chocolate diet?"
response_generator = bot.stream_response(query)

# %%
response = " ".join(token for token in response_generator)
print(response)

# %%
session_id_list = bot.get_previous_conversations()
session_id = session_id_list[0]
bot.load_session(session_id)
session_id
# Out:
# 'Diet Chat - 2026-05-17 21:15:55'

# %%
for msg in bot.get_messages():
    msg.pretty_print()
# Out:
# ================================ System Message ================================
#
# # Diet Planning Assistant
#
# ## Purpose
#
# You are a diet planning assistant that creates personalized, balanced meal
# plans based on user goals, dietary needs, and preferences through
# progressive information gathering and iterative refinement.
#
# ## Success Criteria
#
# - **Progressive Gathering**: Information is collected one topic at a time
#   without overwhelming users
# - **Efficient Questioning**: Questions build on previous responses without
#   asking for already-known information
# - **Complete Adherence**: Plans meet all dietary restrictions, preferences,
#   and nutritional requirements for stated goals
# - **Medical Soundness**: Recommendations follow safe, evidence-based
#   dietary approaches without extreme or harmful practices
# - **Practical Feasibility**: Plans account for user's cooking time, skill
#   level, and budget constraints when mentioned
# ...

# %% [markdown]
# ## The ChatBotUI

# %%
from ui import PersistentChatBotUI

# %%
chatbot = PersistentChatBotUI(bot)
interface = chatbot.create_ui()

# %%
interface.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## Main application

# %%
# !python main.py
# Out:
# /home/sacha/RAG-course-deeplearning/module-6 - langchain/diet_chat_bot_streaming/logic.py:28: LangChainDeprecationWarning: `connection_string` was deprecated in LangChain 0.2.2 and will be removed in 1.0. Use connection instead.
#   self._initialize_history()
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# ^C
# Keyboard interruption in main thread... closing server.
